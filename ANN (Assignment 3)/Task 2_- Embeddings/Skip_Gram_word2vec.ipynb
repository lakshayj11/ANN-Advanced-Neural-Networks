# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
# %tensorflow_version 1.x
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

t = 1e-5
word_counts = Counter(words)
total_words = len(words)
frequencies = {word: count/(total_words) for word, count in word_counts.items()}
drop_probability = {word: 1 - np.sqrt(t/frequencies[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - drop_probability[int_to_vocab[word]])]# The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    if (idx - R) > 0:
      start = idx - R
    else:
      start = 0
    
    stop = idx + R
    target_words = words[start:idx] + words[idx+1:stop+1]

    # Your code here
    
    return target_words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(initial_value = tf.random_uniform(shape = [n_vocab, n_embedding],minval = -1, maxval = 1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, ids=inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(initial_value = tf.truncated_normal((n_vocab, n_embedding)), name='softmax_weight')# create softmax weight matrix here
    softmax_b = tf.Variable(initial_value = tf.zeros(n_vocab), name="softmax_bias")# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        weights = softmax_w,
        biases = softmax_b,
        labels = labels,
        inputs = embed,
        num_sampled=n_sampled,
        num_classes=n_vocab
    ) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-2aa168c49a56>:13: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 17.9006 0.0376 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 17.6379 0.0209 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 17.3882 0.0209 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 17.4154 0.0211 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 17.1360 0.0209 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 17.0804 0.0208 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 17.0298 0.0208 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 16.8764 0.0210 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 16.7257 0.0210 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 16.6269 0.0210 sec/batch
# Nearest to five: jfk, sixes, idealists, silicates, silk, turin, recasting, thx,
# Nearest to other: enterprising, relegating, carriers, tz, invulnerability, ornaments, chongqing, allergy,
# Nearest to history: ccir, depletion, prakrit, drama, cloaca, milford, brouwer, aside,
# Nearest to system: speeches, partial, vitoria, washes, bitter, herbivore, cleavage, ayy,
# Nearest to up: shawl, dolmen, squadrons, thabit, enthusiastic, enthusiast, tarski, livia,
# Nearest to where: morons, wimp, bringer, artery, fleshy, ermey, nya, ahmedabad,
# Nearest to new: baldr, ill, protesting, broadest, obese, chaldean, tonnage, sovereign,
# Nearest to as: washtenaw, expiring, lovers, donegall, aegon, framers, ufos, clytemnestra,
# Nearest to instance: astute, ambitions, argo, breastplate, misspellings, mincha, washed, lds,
# Nearest to issue: cocks, pederastic, japonic, shaykh, bahnhof, indirect, insist, norse,
# Nearest to pre: creaky, copland, lifetime, zachariah, mabo, analyzer, acquitted, targeting,
# Nearest to nobel: macgregor, mont, phrased, blaxploitation, arquette, mifflin, wattle, incapable,
# Nearest to pope: burnside, layman, patterning, colle, bengals, penalty, ae, lpg,
# Nearest to bible: niigata, connotation, domini, bait, kludge, reworking, rs, ebola,
# Nearest to dr: eugenic, ronson, takes, bigcup, kaw, stings, popper, poole,
# Nearest to applied: recombine, komon, sybil, iie, connelly, aldershot, franciszek, specular,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 16.4474 0.0223 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 16.3682 0.0210 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 16.2137 0.0208 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 16.1652 0.0210 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 15.9919 0.0208 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 15.8710 0.0212 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 15.8201 0.0208 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 15.7033 0.0210 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 15.5963 0.0208 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 15.5020 0.0209 sec/batch
# Nearest to five: jfk, sixes, idealists, silk, recasting, silicates, thx, turin,
# Nearest to other: enterprising, relegating, carriers, chongqing, tz, ornaments, allergy, invulnerability,
# Nearest to history: ccir, depletion, cloaca, shown, brouwer, prakrit, milford, drama,
# Nearest to system: speeches, partial, vitoria, bitter, washes, herbivore, ayy, cleavage,
# Nearest to up: shawl, enthusiastic, squadrons, dolmen, thabit, enthusiast, icp, omnidirectional,
# Nearest to where: wimp, morons, artery, bringer, nya, ermey, oswaldo, enclosures,
# Nearest to new: broadest, tonnage, baldr, ill, protesting, obese, sovereign, subdivision,
# Nearest to as: washtenaw, lovers, donegall, ufos, expiring, clytemnestra, framers, dhtml,
# Nearest to instance: astute, ambitions, argo, breastplate, nailed, misspellings, washed, mincha,
# Nearest to issue: cocks, pederastic, shaykh, bahnhof, japonic, indirect, norse, insist,
# Nearest to pre: creaky, analyzer, lifetime, copland, zachariah, sigma, acquitted, krapina,
# Nearest to nobel: macgregor, mont, mifflin, phrased, blaxploitation, incapable, wattle, arquette,
# Nearest to pope: burnside, layman, colle, patterning, lpg, bengals, lanchester, minster,
# Nearest to bible: niigata, bait, connotation, domini, kludge, reworking, rs, uca,
# Nearest to dr: eugenic, ronson, takes, stings, azhar, bigcup, kaw, popper,
# Nearest to applied: recombine, sybil, komon, iie, specular, aldershot, franciszek, connelly,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 15.4380 0.0218 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 15.2987 0.0206 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 15.2656 0.0208 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 15.1691 0.0208 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 15.0439 0.0208 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 14.9144 0.0209 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 14.8392 0.0208 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 14.7833 0.0208 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 14.6497 0.0209 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 14.5805 0.0210 sec/batch
# Nearest to five: jfk, sixes, idealists, silk, recasting, turin, phagspa, distinctives,
# Nearest to other: enterprising, relegating, carriers, chongqing, averroes, ornaments, invulnerability, tasks,
# Nearest to history: ccir, depletion, cloaca, drama, brouwer, aside, prakrit, pulsation,
# Nearest to system: speeches, partial, vitoria, bitter, herbivore, washes, cleavage, bandung,
# Nearest to up: shawl, enthusiastic, thabit, enthusiast, squadrons, dolmen, tarski, omnidirectional,
# Nearest to where: wimp, morons, artery, bringer, oswaldo, nya, ermey, ahmedabad,
# Nearest to new: tonnage, ill, broadest, sovereign, serrated, chaldean, obese, wein,
# Nearest to as: washtenaw, lovers, donegall, ufos, expiring, tonic, clytemnestra, dhtml,
# Nearest to instance: ambitions, astute, argo, mincha, breastplate, nailed, washed, misspellings,
# Nearest to issue: cocks, pederastic, shaykh, bahnhof, indirect, japonic, insist, tiki,
# Nearest to pre: creaky, copland, lifetime, sigma, analyzer, zachariah, mabo, acquitted,
# Nearest to nobel: mont, macgregor, mifflin, phrased, blaxploitation, incapable, arquette, wattle,
# Nearest to pope: burnside, layman, colle, should, penalty, patterning, bengals, lanchester,
# Nearest to bible: niigata, connotation, bait, domini, kludge, reworking, hf, bnetd,
# Nearest to dr: eugenic, ronson, azhar, takes, stings, bigcup, kaw, charterhouse,
# Nearest to applied: komon, recombine, sybil, aldershot, iie, specular, i, franciszek,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 14.4233 0.0220 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 14.3476 0.0211 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 14.2600 0.0209 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 14.1917 0.0209 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 14.1363 0.0209 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 14.0519 0.0209 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 13.8828 0.0208 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 13.8052 0.0209 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 13.6795 0.0209 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 13.5947 0.0208 sec/batch
# Nearest to five: idealists, sixes, silk, jfk, thx, dts, screenshots, phagspa,
# Nearest to other: enterprising, relegating, invulnerability, chongqing, ornaments, lancia, tasks, discontinuities,
# Nearest to history: ccir, depletion, cloaca, aside, brouwer, drama, prakrit, rearwards,
# Nearest to system: speeches, partial, vitoria, bitter, herbivore, bandung, washes, cleavage,
# Nearest to up: shawl, enthusiast, enthusiastic, thabit, squadrons, protest, livia, paragraphs,
# Nearest to where: wimp, morons, artery, bringer, oswaldo, ermey, cavalli, accumulate,
# Nearest to new: tonnage, ill, obese, genie, wein, protesting, chaldean, unwelcome,
# Nearest to as: washtenaw, lovers, tonic, donegall, expiring, ufos, framers, sra,
# Nearest to instance: astute, ambitions, argo, washed, breastplate, mincha, nailed, kulak,
# Nearest to issue: cocks, bahnhof, indirect, shaykh, pederastic, insist, japonic, tiki,
# Nearest to pre: creaky, analyzer, zachariah, copland, acquitted, krapina, lifetime, sigma,
# Nearest to nobel: mont, mifflin, blaxploitation, macgregor, arquette, phrased, incapable, wattle,
# Nearest to pope: burnside, colle, layman, should, apportionment, lanchester, penalty, bengals,
# Nearest to bible: niigata, domini, bait, connotation, kludge, reworking, bnetd, hf,
# Nearest to dr: eugenic, ronson, stings, azhar, bigcup, takes, kaw, poole,
# Nearest to applied: komon, recombine, sybil, aldershot, iie, specular, balked, i,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 13.6253 0.0219 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 13.5179 0.0209 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 13.3774 0.0208 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 13.3679 0.0211 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 13.2244 0.0210 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 13.2371 0.0211 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 13.1002 0.0158 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 12.9842 0.0210 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 12.7764 0.0210 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 12.7084 0.0211 sec/batch
# Nearest to five: idealists, silk, thx, dts, three, sixes, tenth, screenshots,
# Nearest to other: relegating, enterprising, allergy, averroes, invulnerability, lancia, ornaments, mung,
# Nearest to history: aside, ccir, depletion, enchanter, brouwer, drama, mccarthyism, prakrit,
# Nearest to system: speeches, partial, bandung, herbivore, bitter, vitoria, eclecticism, customers,
# Nearest to up: shawl, squadrons, enthusiast, dolmen, paragraphs, livia, aleppo, enthusiastic,
# Nearest to where: wimp, morons, bringer, oswaldo, artery, accumulate, cavalli, nya,
# Nearest to new: tonnage, protesting, obese, ill, managed, sophia, genie, bdsm,
# Nearest to as: in, framers, donegall, tonic, washtenaw, cycladic, undulating, ufos,
# Nearest to instance: astute, ambitions, argo, kulak, mincha, washed, exposure, nailed,
# Nearest to issue: cocks, bahnhof, shaykh, indirect, insist, pederastic, erzherzog, trofeo,
# Nearest to pre: creaky, lifetime, analyzer, copland, diverted, zachariah, sigma, acquitted,
# Nearest to nobel: mont, blaxploitation, macgregor, mifflin, tighten, phrased, incapable, arquette,
# Nearest to pope: colle, burnside, apportionment, should, lpg, layman, lanchester, sexually,
# Nearest to bible: bait, niigata, domini, kludge, connotation, reworking, bnetd, dimming,
# Nearest to dr: eugenic, ronson, azhar, stings, takes, poole, kaw, projectors,
# Nearest to applied: komon, recombine, aldershot, sybil, iie, specular, balked, malpighi,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 12.7607 0.0219 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 12.5914 0.0210 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 12.4786 0.0209 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 12.4197 0.0208 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 12.3625 0.0209 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 12.2665 0.0209 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 12.1391 0.0209 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 12.0294 0.0209 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 12.0290 0.0211 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 12.0572 0.0209 sec/batch
# Nearest to five: three, in, of, zero, by, a, on, the,
# Nearest to other: invulnerability, enterprising, is, averroes, the, explained, various, ornaments,
# Nearest to history: aside, ccir, enchanter, mccarthyism, rearwards, pulsation, drama, tartaglia,
# Nearest to system: speeches, bandung, partial, herbivore, vitoria, customers, eclecticism, bitter,
# Nearest to up: shawl, use, enthusiastic, the, livia, paragraphs, to, dolmen,
# Nearest to where: wimp, bringer, oswaldo, morons, calming, artery, cavalli, accumulate,
# Nearest to new: tonnage, protesting, ill, stiles, petrified, curdled, obese, lapses,
# Nearest to as: of, and, the, in, a, to, for, that,
# Nearest to instance: astute, ambitions, kulak, argo, exposure, buses, washed, horehound,
# Nearest to issue: cocks, bahnhof, indirect, shaykh, trofeo, pederastic, insist, erzherzog,
# Nearest to pre: creaky, copland, diverted, mabo, lifetime, analyzer, zachariah, sigma,
# Nearest to nobel: mont, blaxploitation, macgregor, mifflin, incapable, tighten, phrased, arquette,
# Nearest to pope: colle, should, apportionment, layman, lpg, sexually, burnside, lanchester,
# Nearest to bible: niigata, bait, domini, kludge, connotation, ebola, bnetd, hf,
# Nearest to dr: eugenic, ronson, azhar, stings, poole, takes, popper, goalie,
# Nearest to applied: recombine, sybil, komon, aldershot, specular, iie, balked, connelly,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 12.0049 0.0220 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 11.8655 0.0210 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 11.7531 0.0209 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 11.6891 0.0209 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 11.7122 0.0211 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 11.5446 0.0209 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 11.4300 0.0210 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 11.5398 0.0210 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 11.3784 0.0207 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 11.2603 0.0209 sec/batch
# Nearest to five: zero, three, one, two, four, nine, eight, seven,
# Nearest to other: to, a, that, is, the, and, be, of,
# Nearest to history: aside, mccarthyism, enchanter, homeopathic, proper, that, drama, rearwards,
# Nearest to system: speeches, for, bandung, bitter, latitude, as, customers, herbivore,
# Nearest to up: it, in, shawl, with, use, for, as, be,
# Nearest to where: was, in, the, bringer, and, also, wimp, calming,
# Nearest to new: four, and, two, or, three, at, which, by,
# Nearest to as: for, to, of, in, and, the, with, a,
# Nearest to instance: ambitions, astute, kulak, buses, argo, exposure, craven, projected,
# Nearest to issue: cocks, indirect, insist, shaykh, bahnhof, pederastic, trofeo, altarpiece,
# Nearest to pre: creaky, diverted, copland, lifetime, analyzer, zachariah, very, adorned,
# Nearest to nobel: mont, blaxploitation, macgregor, tighten, mifflin, entail, mackaye, phrased,
# Nearest to pope: should, lpg, colle, sexually, apportionment, layman, corps, lanchester,
# Nearest to bible: niigata, kludge, domini, bait, connotation, teslas, hf, ebola,
# Nearest to dr: eugenic, ronson, azhar, goalie, stings, poole, popper, takes,
# Nearest to applied: aldershot, recombine, sybil, komon, balked, iie, connelly, malpighi,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 11.3402 0.0219 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 11.2121 0.0210 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 10.9552 0.0210 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 11.1031 0.0210 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 10.9989 0.0210 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 10.9035 0.0209 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 10.8859 0.0216 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 10.8373 0.0215 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 10.6491 0.0218 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 10.6981 0.0220 sec/batch
# Nearest to five: one, two, three, zero, four, eight, seven, nine,
# Nearest to other: are, in, this, that, a, to, it, the,
# Nearest to history: mccarthyism, most, has, aside, federation, enchanter, that, of,
# Nearest to system: scheme, latitude, will, five, that, disks, between, which,
# Nearest to up: for, which, the, with, a, nine, there, can,
# Nearest to where: a, to, was, there, are, also, other, as,
# Nearest to new: at, of, was, one, s, from, it, zero,
# Nearest to as: the, of, to, and, a, in, with, on,
# Nearest to instance: ambitions, kulak, astute, buses, argo, projected, breastplate, exposure,
# Nearest to issue: cocks, indirect, insist, bahnhof, shaykh, pederastic, trofeo, erzherzog,
# Nearest to pre: creaky, diverted, copland, lifetime, adorned, analyzer, schema, very,
# Nearest to nobel: mont, blaxploitation, macgregor, tighten, mifflin, incapable, mackaye, bumps,
# Nearest to pope: lpg, should, apportionment, colle, sexually, lanchester, layman, yardbirds,
# Nearest to bible: niigata, kludge, domini, hf, teslas, bait, asme, ebola,
# Nearest to dr: eugenic, ronson, azhar, goalie, stings, husky, poole, try,
# Nearest to applied: aldershot, recombine, komon, sybil, balked, connelly, iie, nocs,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 10.5342 0.0225 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 10.7485 0.0214 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 10.5844 0.0210 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 10.5080 0.0209 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 10.4730 0.0212 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 10.2181 0.0211 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 10.4053 0.0211 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 10.2718 0.0213 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 10.1378 0.0214 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 10.1360 0.0212 sec/batch
# Nearest to five: three, nine, one, seven, two, four, six, zero,
# Nearest to other: the, to, and, also, of, are, these, has,
# Nearest to history: the, most, as, in, was, his, by, one,
# Nearest to system: with, be, have, the, would, in, by, time,
# Nearest to up: it, with, the, for, were, from, also, on,
# Nearest to where: for, that, the, to, also, as, it, is,
# Nearest to new: was, since, in, united, of, and, one, but,
# Nearest to as: the, in, for, and, a, to, of, by,
# Nearest to instance: ambitions, kulak, astute, projected, buses, argo, mincha, exposure,
# Nearest to issue: indirect, insist, cocks, bahnhof, erzherzog, shaykh, pederastic, chandigarh,
# Nearest to pre: creaky, diverted, schema, form, lifetime, was, adorned, er,
# Nearest to nobel: mont, tighten, blaxploitation, macgregor, added, mackaye, b, bumps,
# Nearest to pope: lpg, should, colle, apportionment, sexually, lanchester, yardbirds, layman,
# Nearest to bible: niigata, hf, connotation, bait, domini, teslas, ebola, asme,
# Nearest to dr: ronson, eugenic, azhar, goalie, husky, try, stings, popper,
# Nearest to applied: aldershot, i, recombine, sybil, hoover, balked, command, cpl,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 10.0648 0.0219 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 10.0585 0.0209 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 9.9932 0.0103 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 9.9150 0.0210 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 9.8489 0.0210 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 9.8181 0.0209 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 9.7821 0.0211 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 9.7110 0.0209 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 9.5973 0.0210 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 9.4884 0.0208 sec/batch
# Nearest to five: one, six, four, three, seven, two, nine, eight,
# Nearest to other: the, to, more, however, or, it, with, of,
# Nearest to history: in, of, also, even, to, five, an, zero,
# Nearest to system: for, it, all, that, however, are, to, in,
# Nearest to up: it, a, of, to, has, there, the, for,
# Nearest to where: a, to, the, be, it, are, for, they,
# Nearest to new: two, eight, nine, six, zero, in, one, seven,
# Nearest to as: in, of, a, and, for, the, were, have,
# Nearest to instance: ambitions, kulak, projected, astute, lascaris, buses, argo, mincha,
# Nearest to issue: indirect, bahnhof, part, wrestler, defined, pederastic, chandigarh, insist,
# Nearest to pre: creaky, were, schema, diverted, adorned, form, lifetime, analyzer,
# Nearest to nobel: mont, tighten, blaxploitation, added, mackaye, b, macgregor, prize,
# Nearest to pope: sexually, lpg, should, colle, lanchester, apportionment, yardbirds, aficionados,
# Nearest to bible: niigata, connotation, teslas, domini, hf, ebola, asme, bait,
# Nearest to dr: ronson, azhar, eugenic, right, goalie, try, husky, clerk,
# Nearest to applied: aldershot, recombine, hoover, sybil, individual, command, permissions, cpl,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 9.4495 0.0217 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 9.5141 0.0216 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 9.3256 0.0209 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 9.1730 0.0210 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 9.2463 0.0208 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 9.1849 0.0210 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 9.3755 0.0208 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 9.2078 0.0214 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 9.0191 0.0210 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 9.0307 0.0209 sec/batch
# Nearest to five: four, six, eight, three, nine, zero, seven, one,
# Nearest to other: is, are, the, to, or, in, this, with,
# Nearest to history: by, of, in, nine, its, united, also, the,
# Nearest to system: for, is, are, some, however, that, to, a,
# Nearest to up: has, is, in, that, for, and, it, there,
# Nearest to where: is, it, a, this, be, to, then, which,
# Nearest to new: in, of, one, and, nine, eight, was, three,
# Nearest to as: the, in, to, that, a, for, it, and,
# Nearest to instance: kulak, ambitions, lascaris, barbara, projected, breastplate, re, astute,
# Nearest to issue: range, another, defined, more, war, while, time, high,
# Nearest to pre: became, various, member, in, united, major, like, and,
# Nearest to nobel: mont, tighten, added, blaxploitation, b, macgregor, mackaye, mancini,
# Nearest to pope: sexually, lpg, should, colle, again, great, apportionment, yardbirds,
# Nearest to bible: niigata, connotation, teslas, domini, defended, kludge, heathrow, hf,
# Nearest to dr: try, azhar, ronson, eugenic, right, husky, stings, shoddy,
# Nearest to applied: usually, it, with, been, however, may, as, some,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 9.0956 0.0218 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 9.0752 0.0208 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 8.7662 0.0209 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 8.8764 0.0209 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 8.9669 0.0208 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 8.6877 0.0208 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 8.7850 0.0209 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 8.8918 0.0213 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 8.4927 0.0209 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 8.7128 0.0209 sec/batch
# Nearest to five: eight, three, seven, zero, four, six, one, two,
# Nearest to other: a, is, it, the, that, there, have, only,
# Nearest to history: of, to, on, in, and, the, two, by,
# Nearest to system: is, its, to, be, such, as, the, and,
# Nearest to up: a, only, to, is, the, time, that, by,
# Nearest to where: a, of, the, to, is, only, and, in,
# Nearest to new: in, and, the, to, been, of, from, at,
# Nearest to as: the, a, some, in, of, that, to, it,
# Nearest to instance: kulak, language, not, this, important, find, point, same,
# Nearest to issue: had, new, s, from, range, world, made, time,
# Nearest to pre: because, in, various, major, to, only, written, from,
# Nearest to nobel: mont, b, prize, added, tighten, blaxploitation, french, swedish,
# Nearest to pope: sexually, lpg, colle, entangling, apportionment, yardbirds, school, lanchester,
# Nearest to bible: niigata, connotation, defended, contains, heathrow, teslas, domini, dimming,
# Nearest to dr: her, database, try, countries, husky, left, right, stings,
# Nearest to applied: given, same, certain, usually, order, can, number, between,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 8.6640 0.0220 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 8.5099 0.0210 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 8.4968 0.0211 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 8.4824 0.0210 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 8.3730 0.0210 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 8.3464 0.0210 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 8.2721 0.0209 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 8.4358 0.0208 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 8.3280 0.0208 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 8.2495 0.0209 sec/batch
# Nearest to five: seven, four, six, one, three, two, eight, zero,
# Nearest to other: to, are, the, an, all, this, a, also,
# Nearest to history: and, the, was, of, in, by, from, a,
# Nearest to system: are, is, its, however, use, the, these, an,
# Nearest to up: a, on, for, of, the, to, as, and,
# Nearest to where: to, as, the, but, of, and, for, in,
# Nearest to new: the, a, was, and, in, of, to, on,
# Nearest to as: the, to, of, and, a, which, on, it,
# Nearest to instance: an, are, is, find, same, any, can, when,
# Nearest to issue: to, and, the, in, a, while, was, of,
# Nearest to pre: in, around, now, as, few, language, more, the,
# Nearest to nobel: prize, b, nine, american, eight, seven, robert, one,
# Nearest to pope: sexually, england, king, roman, colle, father, city, lpg,
# Nearest to bible: niigata, defended, contains, should, heathrow, shortly, connotation, deadly,
# Nearest to dr: her, his, stage, man, get, century, story, king,
# Nearest to applied: can, to, a, not, these, they, are, an,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 8.4504 0.0219 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 8.0554 0.0209 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 8.3525 0.0209 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 8.1766 0.0211 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 8.0011 0.0209 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 8.0932 0.0213 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 8.1024 0.0212 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 8.0665 0.0210 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 8.0676 0.0049 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 7.8978 0.0208 sec/batch
# Nearest to five: eight, three, zero, one, seven, six, two, nine,
# Nearest to other: the, to, of, which, more, and, a, in,
# Nearest to history: the, s, of, and, was, in, from, th,
# Nearest to system: for, to, is, systems, be, all, without, use,
# Nearest to up: the, which, to, with, a, could, in, even,
# Nearest to where: a, the, to, be, of, is, are, because,
# Nearest to new: first, at, united, the, of, in, and, on,
# Nearest to as: the, of, to, for, a, from, in, that,
# Nearest to instance: is, be, any, a, that, are, more, must,
# Nearest to issue: was, year, of, on, new, first, end, for,
# Nearest to pre: of, only, to, part, also, seen, and, a,
# Nearest to nobel: prize, b, d, american, british, author, writer, seven,
# Nearest to pope: england, king, sexually, father, name, great, city, became,
# Nearest to bible: defended, force, so, niigata, quotes, deadly, tradition, heathrow,
# Nearest to dr: before, released, get, end, stage, mid, right, left,
# Nearest to applied: can, so, such, or, other, to, each, used,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 7.9651 0.0219 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 7.9547 0.0207 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 7.7637 0.0208 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 7.9003 0.0208 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 7.7143 0.0209 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 7.6064 0.0209 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 7.6825 0.0210 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 7.6755 0.0209 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 7.6172 0.0209 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 7.3268 0.0209 sec/batch
# Nearest to five: three, six, one, eight, seven, two, zero, four,
# Nearest to other: of, with, are, such, be, the, to, for,
# Nearest to history: the, under, in, of, and, by, as, before,
# Nearest to system: systems, it, use, computer, is, its, for, to,
# Nearest to up: the, to, with, of, a, other, for, and,
# Nearest to where: a, to, and, it, is, are, all, of,
# Nearest to new: the, s, in, and, united, of, on, at,
# Nearest to as: to, the, and, a, of, in, this, that,
# Nearest to instance: not, is, more, be, or, this, a, some,
# Nearest to issue: s, of, an, at, was, its, there, in,
# Nearest to pre: of, a, this, major, with, no, in, and,
# Nearest to nobel: prize, d, writer, b, born, american, robert, french,
# Nearest to pope: england, father, son, john, king, roman, january, iii,
# Nearest to bible: christian, book, events, quotes, command, written, least, subsequent,
# Nearest to dr: get, s, personal, brought, inspired, six, story, home,
# Nearest to applied: is, are, used, some, can, this, as, be,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 7.4220 0.0220 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 7.4762 0.0208 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 7.6082 0.0209 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 7.5999 0.0208 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 7.3894 0.0208 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 7.4307 0.0210 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 7.4238 0.0209 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 7.4723 0.0210 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 7.1436 0.0209 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 7.2413 0.0210 sec/batch
# Nearest to five: three, six, eight, nine, one, four, seven, zero,
# Nearest to other: to, for, have, and, they, be, of, in,
# Nearest to history: in, the, world, of, new, under, people, at,
# Nearest to system: systems, is, a, such, of, for, available, there,
# Nearest to up: it, for, the, to, with, this, in, they,
# Nearest to where: a, this, to, of, is, the, for, that,
# Nearest to new: in, of, the, and, as, was, s, to,
# Nearest to as: and, of, the, in, for, to, that, an,
# Nearest to instance: can, is, be, are, example, that, if, used,
# Nearest to issue: to, all, of, since, by, in, people, its,
# Nearest to pre: of, in, all, major, the, and, many, into,
# Nearest to nobel: prize, writer, born, b, american, david, french, d,
# Nearest to pope: father, son, iii, king, roman, john, leader, became,
# Nearest to bible: command, upon, quotes, why, concern, christian, least, nature,
# Nearest to dr: john, now, stage, september, early, michael, death, man,
# Nearest to applied: be, that, is, can, a, are, example, all,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 7.3089 0.0221 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 7.2049 0.0210 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 7.2600 0.0210 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 7.3206 0.0210 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 7.0282 0.0214 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 7.0306 0.0209 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 7.1836 0.0209 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 7.0706 0.0211 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 7.0434 0.0209 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 7.0974 0.0208 sec/batch
# Nearest to five: two, three, eight, one, zero, six, four, nine,
# Nearest to other: a, to, an, it, this, which, have, in,
# Nearest to history: of, in, europe, was, and, the, th, from,
# Nearest to system: systems, to, for, are, using, number, this, can,
# Nearest to up: a, with, for, an, its, which, on, to,
# Nearest to where: a, this, is, there, number, are, with, all,
# Nearest to new: of, the, was, had, in, and, by, to,
# Nearest to as: the, to, its, of, and, a, for, most,
# Nearest to instance: be, or, is, which, an, this, only, are,
# Nearest to issue: of, to, the, its, several, it, and, would,
# Nearest to pre: as, to, period, in, most, by, of, the,
# Nearest to nobel: prize, writer, b, american, born, david, physicist, eight,
# Nearest to pope: catholic, father, his, roman, king, iv, stephen, iii,
# Nearest to bible: believe, chosen, why, christian, quotes, should, upon, neither,
# Nearest to dr: his, career, s, david, becoming, ended, michael, story,
# Nearest to applied: are, is, this, or, can, be, so, than,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 7.1038 0.0219 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 6.8295 0.0208 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 6.8748 0.0212 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 7.0275 0.0210 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 6.9748 0.0210 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 6.9313 0.0212 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 7.1615 0.0209 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 6.7332 0.0210 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 7.0014 0.0210 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 6.9564 0.0210 sec/batch
# Nearest to five: four, zero, three, one, two, seven, eight, six,
# Nearest to other: to, the, from, of, and, a, but, also,
# Nearest to history: of, in, by, the, was, from, europe, most,
# Nearest to system: systems, available, use, this, however, are, is, free,
# Nearest to up: to, the, in, with, and, of, on, for,
# Nearest to where: the, for, to, a, by, that, as, and,
# Nearest to new: in, was, of, on, after, s, world, first,
# Nearest to as: the, a, to, with, and, of, have, it,
# Nearest to instance: can, are, or, will, this, be, is, exist,
# Nearest to issue: to, a, the, was, and, from, however, not,
# Nearest to pre: in, also, by, more, the, to, most, from,
# Nearest to nobel: prize, writer, american, b, actor, d, physicist, author,
# Nearest to pope: catholic, charles, king, iv, william, father, iii, church,
# Nearest to bible: tradition, teaching, ancient, biblical, quotes, theology, idea, upon,
# Nearest to dr: david, eight, himself, death, seven, he, robert, in,
# Nearest to applied: this, these, which, that, are, such, is, be,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 6.6778 0.0218 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 6.7759 0.0209 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 6.7927 0.0210 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 6.8315 0.0209 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 6.8473 0.0209 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 6.6872 0.0203 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 6.7360 0.0208 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 6.8383 0.0209 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 6.5862 0.0209 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 6.7719 0.0210 sec/batch
# Nearest to five: one, four, seven, six, three, two, zero, eight,
# Nearest to other: to, it, more, is, a, as, with, are,
# Nearest to history: in, the, world, of, at, s, was, first,
# Nearest to system: systems, be, is, using, a, use, used, required,
# Nearest to up: a, the, with, and, to, by, at, as,
# Nearest to where: a, it, is, more, same, only, to, as,
# Nearest to new: in, s, at, the, during, of, and, united,
# Nearest to as: a, the, to, of, with, it, in, by,
# Nearest to instance: be, can, more, some, if, is, other, because,
# Nearest to issue: their, by, to, people, was, for, modern, and,
# Nearest to pre: the, from, and, of, as, its, to, that,
# Nearest to nobel: prize, d, writer, b, american, physicist, actor, chemist,
# Nearest to pope: catholic, iv, king, son, iii, henry, father, church,
# Nearest to bible: biblical, tradition, translated, christian, books, teaching, according, theology,
# Nearest to dr: british, s, one, in, sir, english, and, american,
# Nearest to applied: often, be, can, examples, non, is, this, or,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 6.6120 0.0218 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 6.4818 0.0209 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 6.5485 0.0216 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 6.5865 0.0212 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 6.5426 0.0209 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 6.3309 0.0210 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 6.3027 0.0209 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 6.4030 0.0209 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 6.4777 0.0211 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 6.5237 0.0211 sec/batch
# Nearest to five: three, seven, zero, six, one, nine, two, four,
# Nearest to other: to, with, for, some, a, such, are, or,
# Nearest to history: of, in, s, the, part, new, now, links,
# Nearest to system: systems, program, to, be, information, such, for, which,
# Nearest to up: a, with, the, while, it, to, before, at,
# Nearest to where: a, for, is, be, which, each, the, this,
# Nearest to new: s, began, the, one, in, two, year, at,
# Nearest to as: to, the, that, which, for, of, a, in,
# Nearest to instance: be, any, simply, or, not, specific, way, required,
# Nearest to issue: to, by, of, the, in, but, on, and,
# Nearest to pre: in, and, today, by, its, of, several, speaking,
# Nearest to nobel: prize, writer, physicist, d, actor, chemist, poet, singer,
# Nearest to pope: king, iv, son, iii, catholic, henry, rome, joseph,
# Nearest to bible: biblical, christian, scholars, book, texts, old, books, translated,
# Nearest to dr: american, one, scientist, richard, director, born, nine, seven,
# Nearest to applied: be, use, are, or, is, which, can, such,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 6.3108 0.0221 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 6.3772 0.0210 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 6.4250 0.0211 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 6.4197 0.0210 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 6.3427 0.0209 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 6.1941 0.0210 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 6.2977 0.0210 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 6.3262 0.0209 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 6.2339 0.0210 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 6.3957 0.0210 sec/batch
# Nearest to five: one, six, eight, three, zero, four, nine, seven,
# Nearest to other: to, as, is, it, the, such, some, a,
# Nearest to history: of, the, in, been, and, early, with, came,
# Nearest to system: systems, using, available, multiple, process, can, program, is,
# Nearest to up: a, the, it, to, for, which, on, as,
# Nearest to where: a, to, with, for, which, the, same, often,
# Nearest to new: in, was, and, s, at, the, after, with,
# Nearest to as: the, to, of, and, a, that, with, well,
# Nearest to instance: example, can, is, any, it, be, this, if,
# Nearest to issue: and, of, to, the, in, from, people, by,
# Nearest to pre: in, and, by, to, of, from, the, into,
# Nearest to nobel: prize, physicist, writer, recipient, nine, actor, d, american,
# Nearest to pope: catholic, iii, roman, son, king, rome, church, holy,
# Nearest to bible: biblical, christian, texts, scholars, god, testament, believe, books,
# Nearest to dr: producer, career, david, john, director, richard, seven, best,
# Nearest to applied: can, or, are, more, is, it, which, any,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 6.1924 0.0219 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 6.0981 0.0210 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 6.2572 0.0210 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 6.1928 0.0210 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 6.1556 0.0208 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 6.1880 0.0208 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 6.2499 0.0209 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 5.9438 0.0209 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 6.0775 0.0209 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 6.0136 0.0210 sec/batch
# Nearest to five: six, one, eight, three, seven, four, two, zero,
# Nearest to other: a, which, with, to, there, this, for, are,
# Nearest to history: and, historical, in, the, see, of, world, new,
# Nearest to system: systems, use, program, designed, are, using, multiple, available,
# Nearest to up: a, on, to, so, making, as, with, out,
# Nearest to where: a, for, this, is, there, as, of, an,
# Nearest to new: s, and, the, in, of, united, at, on,
# Nearest to as: to, with, this, their, for, the, a, that,
# Nearest to instance: be, this, is, are, any, using, so, can,
# Nearest to issue: to, by, on, and, the, people, in, issues,
# Nearest to pre: in, the, its, late, were, people, of, most,
# Nearest to nobel: prize, physicist, chemist, american, recipient, d, writer, scientist,
# Nearest to pope: catholic, roman, church, rome, emperor, king, iii, holy,
# Nearest to bible: biblical, testament, texts, scholars, god, christian, jewish, writings,
# Nearest to dr: robert, american, david, author, physician, richard, producer, john,
# Nearest to applied: simply, be, are, can, is, form, such, specific,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 6.1638 0.0219 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 6.1086 0.0213 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 6.2358 0.0211 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 6.1171 0.0214 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 5.9822 0.0217 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 6.2313 0.0218 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 6.0000 0.0216 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 5.9318 0.0217 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 5.9620 0.0213 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 5.9913 0.0210 sec/batch
# Nearest to five: three, four, one, six, eight, seven, two, nine,
# Nearest to other: to, as, the, or, which, of, it, and,
# Nearest to history: of, historical, in, s, was, by, today, early,
# Nearest to system: systems, use, applications, required, access, programs, operating, allows,
# Nearest to up: a, to, with, as, for, the, have, than,
# Nearest to where: a, the, to, is, be, for, as, and,
# Nearest to new: first, at, s, on, since, in, of, united,
# Nearest to as: the, to, a, and, that, for, have, of,
# Nearest to instance: using, particular, be, can, simply, different, are, each,
# Nearest to issue: until, attempted, was, been, by, did, legal, an,
# Nearest to pre: of, many, in, by, as, these, also, its,
# Nearest to nobel: prize, physicist, chemist, american, d, b, physiology, recipient,
# Nearest to pope: iii, king, henry, charles, emperor, catholic, son, iv,
# Nearest to bible: biblical, testament, scholars, god, tradition, christian, christianity, texts,
# Nearest to dr: david, one, john, nine, producer, four, peter, three,
# Nearest to applied: simply, be, apply, is, or, methods, problems, context,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 6.0892 0.0218 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 5.9730 0.0150 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 5.9509 0.0214 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 6.0404 0.0213 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 5.8939 0.0213 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 5.9508 0.0210 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 5.9918 0.0212 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 5.7315 0.0211 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 5.8612 0.0212 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 5.8275 0.0210 sec/batch
# Nearest to five: three, four, six, one, two, zero, seven, eight,
# Nearest to other: are, is, for, some, to, which, have, it,
# Nearest to history: of, in, the, century, and, great, known, historical,
# Nearest to system: systems, applications, display, access, use, multiple, provides, operating,
# Nearest to up: a, to, with, and, the, have, about, of,
# Nearest to where: a, for, and, an, to, which, the, is,
# Nearest to new: york, was, first, s, in, the, at, during,
# Nearest to as: a, to, of, and, for, the, in, it,
# Nearest to instance: values, complex, value, simply, example, require, are, does,
# Nearest to issue: public, of, the, for, by, to, in, people,
# Nearest to pre: of, and, in, has, the, for, from, were,
# Nearest to nobel: prize, physicist, d, recipient, chemist, laureate, journalist, scientist,
# Nearest to pope: king, iii, iv, henry, rome, charles, viii, duke,
# Nearest to bible: testament, biblical, hebrew, books, god, texts, christianity, christian,
# Nearest to dr: american, one, producer, richard, artist, nine, s, stephen,
# Nearest to applied: is, generally, are, such, common, different, means, example,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 5.8822 0.0220 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 5.6495 0.0210 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 5.6199 0.0209 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 5.6861 0.0217 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 5.7660 0.0210 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 5.8732 0.0210 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 5.6837 0.0209 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 5.7528 0.0210 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 5.7097 0.0210 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 5.8390 0.0213 sec/batch
# Nearest to five: three, six, eight, seven, four, zero, one, two,
# Nearest to other: this, are, not, to, or, as, also, all,
# Nearest to history: old, people, in, new, early, historical, world, century,
# Nearest to system: systems, available, applications, operating, program, computer, are, programs,
# Nearest to up: the, a, with, at, and, from, to, they,
# Nearest to where: a, this, then, the, of, to, for, be,
# Nearest to new: s, was, on, state, and, york, began, early,
# Nearest to as: of, the, to, from, they, by, this, and,
# Nearest to instance: can, this, are, such, values, any, be, example,
# Nearest to issue: did, and, to, the, on, was, early, by,
# Nearest to pre: in, and, the, today, varied, some, to, of,
# Nearest to nobel: prize, physicist, laureate, chemist, american, recipient, journalist, poet,
# Nearest to pope: king, rome, holy, viii, catholic, iii, roman, son,
# Nearest to bible: biblical, testament, hebrew, book, god, christian, texts, books,
# Nearest to dr: producer, american, one, nine, robert, artist, richard, director,
# Nearest to applied: physical, this, such, apply, be, is, rather, are,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 5.8006 0.0218 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 5.5660 0.0209 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 5.6740 0.0210 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 5.6806 0.0210 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 5.6099 0.0210 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 5.7490 0.0209 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 5.6622 0.0210 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 5.4651 0.0211 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 5.6359 0.0209 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 5.6874 0.0211 sec/batch
# Nearest to five: eight, three, one, six, zero, four, two, nine,
# Nearest to other: more, the, are, as, with, to, or, usually,
# Nearest to history: early, new, in, historical, from, th, late, references,
# Nearest to system: systems, provide, operating, programs, access, available, program, information,
# Nearest to up: a, on, for, just, than, with, to, the,
# ...
# Nearest to bible: testament, biblical, hebrew, tanakh, book, books, translations, prophets,
# Nearest to dr: doctor, producer, director, robert, dean, novel, miller, richard,
# Nearest to applied: these, such, theoretical, structure, certain, physical, pure, is,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 4.6648 0.0222 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 4.6089 0.0212 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 4.6563 0.0208 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 4.6580 0.0211 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 4.7715 0.0212 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 4.6809 0.0215 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 4.6969 0.0211 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 4.6799 0.0211 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 4.7666 0.0212 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 4.7584 0.0213 sec/batch
# Nearest to five: three, six, eight, four, seven, zero, two, one,
# Nearest to other: is, are, as, such, to, there, and, or,
# Nearest to history: links, references, external, list, historical, encyclopedia, timeline, archives,
# Nearest to system: systems, available, application, operating, use, implementation, implement, require,
# Nearest to up: with, at, on, time, when, a, the, out,
# Nearest to where: then, a, the, this, given, to, is, if,
# Nearest to new: york, s, nine, one, at, was, and, zero,
# Nearest to as: of, in, the, and, to, many, from, other,
# Nearest to instance: example, any, can, be, is, defined, exist, possible,
# Nearest to issue: been, regarding, examining, issues, responsible, actions, seek, rejected,
# Nearest to pre: part, among, widely, western, middle, modern, considered, mostly,
# Nearest to nobel: prize, laureate, physicist, chemist, recipient, politician, writer, d,
# Nearest to pope: bishop, xiii, viii, xii, papal, ix, archbishop, bishops,
# Nearest to bible: testament, biblical, tanakh, hebrew, prophets, translations, book, scriptures,
# Nearest to dr: personality, dick, adaptation, producer, artist, appeared, director, harvey,
# Nearest to applied: theory, basis, be, fields, mathematical, theoretical, approach, example,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 4.5961 0.0220 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 4.6587 0.0213 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 4.7422 0.0209 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 4.6574 0.0210 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 4.7298 0.0211 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.6420 0.0209 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.6011 0.0210 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 4.6827 0.0209 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.6889 0.0209 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 4.6639 0.0209 sec/batch
# Nearest to five: six, three, four, eight, two, one, seven, zero,
# Nearest to other: there, have, as, some, which, common, such, more,
# Nearest to history: historical, century, of, in, see, historian, origins, th,
# Nearest to system: systems, operating, use, program, provide, access, existing, implementation,
# Nearest to up: with, on, down, a, next, to, off, being,
# Nearest to where: a, is, above, this, be, the, an, then,
# Nearest to new: in, and, of, was, s, world, now, the,
# Nearest to as: the, some, of, in, to, and, by, with,
# Nearest to instance: be, example, this, is, or, all, not, but,
# Nearest to issue: rejected, rights, regarding, agenda, become, matters, to, political,
# Nearest to pre: numerous, several, also, western, as, in, by, and,
# Nearest to nobel: prize, laureate, physicist, chemist, recipient, physiology, writer, d,
# Nearest to pope: xiii, bishop, viii, rome, xii, papal, iii, catholic,
# Nearest to bible: testament, biblical, tanakh, translations, hebrew, prophets, scholars, texts,
# Nearest to dr: producer, director, writer, robert, lee, david, michael, american,
# Nearest to applied: analysis, which, theoretical, such, be, theory, form, certain,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 4.7028 0.0219 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 4.6676 0.0211 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 4.5209 0.0209 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 4.5822 0.0211 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.6097 0.0211 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 4.6025 0.0209 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.7301 0.0208 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 4.7852 0.0207 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 4.7335 0.0208 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 4.5562 0.0209 sec/batch
# Nearest to five: four, six, zero, two, three, one, seven, eight,
# Nearest to other: most, some, has, to, common, generally, more, or,
# Nearest to history: of, see, historical, origins, europe, in, th, culture,
# Nearest to system: systems, use, provides, operating, via, provide, existing, access,
# Nearest to up: off, once, back, to, when, out, and, with,
# Nearest to where: the, there, a, is, an, then, and, this,
# Nearest to new: york, first, s, nine, on, and, now, from,
# Nearest to as: the, and, a, to, some, which, all, but,
# Nearest to instance: example, or, can, corresponding, is, this, defined, any,
# Nearest to issue: issues, rejected, rights, legislation, regarding, government, matters, to,
# Nearest to pre: middle, cultures, in, modern, eastern, primarily, known, numerous,
# Nearest to nobel: prize, laureate, physicist, physiology, chemist, american, writer, biologist,
# Nearest to pope: xii, viii, xiii, bishop, catholic, papal, rome, archbishop,
# Nearest to bible: testament, biblical, tanakh, prophets, passages, hebrew, translation, scriptures,
# Nearest to dr: author, writer, robert, physician, david, american, barbara, miller,
# Nearest to applied: terms, basis, theoretical, study, knowledge, theory, proposed, law,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 4.6286 0.0217 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.6351 0.0210 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 4.5361 0.0209 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 4.5783 0.0210 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.6057 0.0211 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.6979 0.0208 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 4.6359 0.0143 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 4.5699 0.0210 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 4.6484 0.0211 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.5845 0.0215 sec/batch
# Nearest to five: four, one, seven, three, six, two, eight, nine,
# Nearest to other: has, such, for, more, as, with, a, or,
# Nearest to history: historical, and, world, culture, of, external, links, origins,
# Nearest to system: systems, operating, components, access, program, communication, provide, available,
# Nearest to up: out, once, off, time, when, back, down, a,
# Nearest to where: a, the, is, above, it, with, for, be,
# Nearest to new: on, s, california, york, united, states, public, a,
# Nearest to as: a, the, to, in, by, with, which, this,
# Nearest to instance: example, different, particular, essentially, be, always, this, either,
# Nearest to issue: government, legal, matters, did, officials, rights, agenda, issues,
# Nearest to pre: as, and, middle, culture, in, part, earliest, which,
# Nearest to nobel: prize, laureate, physicist, chemist, d, recipient, b, physiology,
# Nearest to pope: xii, iv, viii, iii, innocent, bishop, xiii, vii,
# Nearest to bible: testament, biblical, tanakh, prophets, hebrew, scriptures, scripture, passages,
# Nearest to dr: director, robert, doctor, personality, author, mr, barbara, producer,
# Nearest to applied: these, structure, this, such, terms, theoretical, modern, contrast,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.5765 0.0219 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 4.6393 0.0210 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 4.4995 0.0210 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.5296 0.0208 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.5828 0.0211 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 4.5736 0.0209 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.4972 0.0211 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.4079 0.0211 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.4967 0.0210 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.4726 0.0212 sec/batch
# Nearest to five: four, three, zero, six, seven, eight, two, one,
# Nearest to other: to, the, and, many, is, have, of, these,
# Nearest to history: historical, links, article, culture, list, origins, external, encyclopedia,
# Nearest to system: systems, operating, provides, for, multi, program, communication, components,
# Nearest to up: out, time, they, down, at, a, make, off,
# Nearest to where: is, then, the, a, this, for, of, above,
# Nearest to new: united, on, york, s, at, city, public, state,
# Nearest to as: a, to, and, of, the, with, from, in,
# Nearest to instance: that, is, complex, this, any, be, rather, simply,
# Nearest to issue: regarding, stated, rights, issues, personal, attempts, interested, debate,
# Nearest to pre: several, mainly, part, and, cultures, in, history, culture,
# Nearest to nobel: prize, laureate, physicist, chemist, recipient, writer, physiology, biologist,
# Nearest to pope: xii, papal, viii, xiii, ix, xvi, papacy, vii,
# Nearest to bible: testament, biblical, tanakh, hebrew, book, prophets, translations, texts,
# Nearest to dr: director, personality, author, producer, american, dean, robert, actor,
# Nearest to applied: these, concept, is, used, of, such, particular, be,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 4.5365 0.0220 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.5116 0.0210 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.5412 0.0211 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.4783 0.0212 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.5647 0.0210 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.6081 0.0209 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.4461 0.0210 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.4374 0.0210 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.5386 0.0209 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.4573 0.0211 sec/batch
# Nearest to five: zero, three, four, two, six, eight, seven, nine,
# Nearest to other: some, are, as, common, these, there, often, have,
# Nearest to history: historical, links, external, encyclopedia, see, online, origins, articles,
# Nearest to system: systems, provides, representation, its, general, provided, internal, required,
# Nearest to up: to, than, off, down, another, on, when, time,
# Nearest to where: a, an, for, then, which, is, to, times,
# Nearest to new: and, york, at, by, in, s, on, major,
# Nearest to as: in, to, this, that, many, a, the, which,
# Nearest to instance: example, is, this, any, be, can, particular, that,
# Nearest to issue: regarding, issues, rights, concluded, agenda, efforts, rejected, future,
# Nearest to pre: many, also, in, several, these, of, to, largely,
# Nearest to nobel: prize, laureate, physicist, chemist, politician, writer, scientist, physiology,
# Nearest to pope: xii, papal, xiii, viii, papacy, gregory, innocent, archbishop,
# Nearest to bible: testament, biblical, hebrew, tanakh, prophets, translations, scriptures, scripture,
# Nearest to dr: jones, appeared, producer, michael, david, doctor, director, actor,
# Nearest to applied: such, theoretical, means, contrast, this, method, methods, specific,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.5512 0.0219 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.5228 0.0210 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.4260 0.0211 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.4753 0.0209 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.5736 0.0210 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.4902 0.0209 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.4612 0.0212 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.5140 0.0212 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.4224 0.0212 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.4271 0.0210 sec/batch
# Nearest to five: six, three, four, one, seven, zero, two, eight,
# Nearest to other: are, as, some, such, the, in, or, is,
# Nearest to history: historical, external, list, links, timeline, see, modern, ancient,
# Nearest to system: systems, use, access, operating, allows, provides, for, via,
# Nearest to up: to, end, another, made, off, a, down, on,
# Nearest to where: a, of, this, then, and, the, there, in,
# Nearest to new: and, of, the, s, now, from, community, on,
# Nearest to as: such, the, these, this, some, are, which, and,
# Nearest to instance: example, is, be, definition, particular, defined, are, any,
# Nearest to issue: regarding, rights, issues, laws, agenda, justice, legal, agreement,
# Nearest to pre: modern, th, most, early, earliest, centuries, in, many,
# Nearest to nobel: prize, physicist, laureate, chemist, physiology, scientist, biologist, recipient,
# Nearest to pope: papal, xiii, bishops, papacy, catholic, bishop, schism, church,
# Nearest to bible: testament, biblical, tanakh, translations, prophets, texts, hebrew, scripture,
# Nearest to dr: director, movie, personality, miller, titled, robert, producer, mike,
# Nearest to applied: terms, such, method, concepts, principles, concept, refers, definitions,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.4140 0.0221 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.4808 0.0209 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.5566 0.0210 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.5758 0.0208 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.6165 0.0210 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.3915 0.0209 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.4714 0.0209 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.4746 0.0210 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.3632 0.0209 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.4209 0.0211 sec/batch
# Nearest to five: two, six, three, seven, eight, four, one, nine,
# Nearest to other: are, has, which, than, more, or, also, for,
# Nearest to history: world, historical, culture, links, extensive, of, today, in,
# Nearest to system: systems, provides, access, operating, implementation, multi, based, development,
# Nearest to up: off, down, spot, being, behind, track, ready, out,
# Nearest to where: a, then, is, so, it, only, to, given,
# Nearest to new: york, by, s, in, united, on, currently, first,
# Nearest to as: a, to, and, the, an, with, while, which,
# Nearest to instance: be, example, can, or, simply, not, particular, certain,
# Nearest to issue: adopt, rights, adopted, been, agreement, authorities, authority, peace,
# Nearest to pre: modern, cultures, most, historical, archaic, centuries, language, middle,
# Nearest to nobel: prize, laureate, physicist, chemist, physiology, american, d, writer,
# Nearest to pope: xiii, xii, papal, benedict, archbishop, viii, bishop, bishops,
# Nearest to bible: tanakh, testament, biblical, hebrew, prophets, scriptures, texts, scripture,
# Nearest to dr: robert, jr, personality, hospital, director, lee, doctor, author,
# Nearest to applied: analysis, theory, study, concepts, method, specific, formulation, theoretical,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.4766 0.0222 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.4366 0.0211 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
